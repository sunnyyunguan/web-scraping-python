# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'}).text.strip()

    except AttributeError:
        title = ""

    return title

# Function to extract discounted Product Price
def get_discounted_price(soup):
    try:
        discounted_price = soup.find("div", attrs={"class":'a-section a-spacing-micro'}).find("span", attrs={"class": "a-price aok-align-center"}).find("span", attrs={"class": "a-offscreen"}).text.strip()

    except AttributeError:
        discounted_price = ""

    return discounted_price

# Function to extract discount
def get_discount(soup):
    try:
        discount = new_soup.find("div", attrs={"class",'a-section a-spacing-none aok-align-center'}).find("span", attrs={"class":'a-size-large a-color-price savingPriceOverride aok-align-center reinventPriceSavingsPercentageMargin savingsPercentage'}).text.strip()
        
    except AttributeError:
        discount = ""

    return discount

# Function to extract Product Price
def get_price(soup):
    try:
        price = soup.find("div", attrs={"class",'a-section a-spacing-small aok-align-center'}).find("span", attrs={"class",'a-size-small a-color-secondary aok-align-center basisPrice'}).find("span", attrs={"class", 'a-offscreen'}).text.strip()

    except AttributeError:
        price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).text.strip()
    
    except AttributeError:
            rating = ""

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).text.strip()

    except AttributeError:
        review_count = ""

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'}).text.strip()

    except AttributeError:
        available = "Not Available"

    return available

# %%
# add your user agent 
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

# The webpage URL
URL = "https://www.amazon.com/s?k=hand+bags&rh=n%3A7141123011%2Cp_89%3AFossil&dc&ds=v1%3Aw5ZdMJJeUUMNrP3PZsYx%2FdzaVyD2ArRTS7hLCXtpaGQ&crid=23XIRL07U9CLD&qid=1671547150&rnid=2528832011&sprefix=hand+bags%2Caps%2C127&ref=sr_nr_p_89_2"

# HTTP Request
webpage = requests.get(URL, headers=HEADERS)

# Soup Object containing all data
soup = BeautifulSoup(webpage.content, "html.parser")

# Fetch links as List of Tag Objects
links = soup.find_all("a", attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# Store the links
links_list = []

d = {"title":[], "discounted_price":[], "discount_percent":[], "price":[], "rating":[], "reviews":[],"availability":[]}

# Loop for extracting links from Tag Objects
for link in links:
        links_list.append(link.get('href'))

# Loop for extracting product details from each link 
for link in links_list:
    new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

    new_soup = BeautifulSoup(new_webpage.content, "html.parser")

    # Function calls to display all necessary product information
    d['title'].append(get_title(new_soup))
    d['discounted_price'].append(get_discounted_price(new_soup))
    d['discount_percent'].append(get_discount(new_soup))
    d['price'].append(get_price(new_soup))
    d['rating'].append(get_rating(new_soup))
    d['reviews'].append(get_review_count(new_soup))
    d['availability'].append(get_availability(new_soup))

# clean up
df = pd.DataFrame.from_dict(d)
df['title'].replace('', np.nan, inplace=True)
df = df.dropna(subset=['title'])

df['discounted_price'] = pd.to_numeric(df['discounted_price'].replace(r'\$', '',regex=True))
df['discount_percent'] = pd.to_numeric(df['discount_percent'].map(lambda x: x.rstrip('%')))
df['price'] = pd.to_numeric(df['price'].replace(r'\$', '',regex=True))
df['rating'] = pd.to_numeric(df['rating'].replace(r'\ out of 5 stars', '',regex=True))
#df['reviews'] = pd.to_numeric(df['reviews'].replace(r'\ ratings', '',regex=True).replace(',',''),downcast ='signed')
df['reviews'] = df['reviews'].replace(r'\ ratings', '',regex=True)
df['availability'] = df['availability'].replace(r'\.', '',regex=True)

#df.to_csv("amazon_data.csv", header=True, index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,936"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17928\2657110249.py in <module>
#      48 df['rating'] = pd.to_numeric(df['rating'].replace(r'\ out of 5 stars', '',regex=True))
#      49 #df['reviews'] = pd.to_numeric(df['reviews'].replace(r'\ ratings', '',regex=True).replace(',',''),downcast ='signed')
# ---> 50 df['reviews'] = pd.to_numeric(df['reviews'].replace(r'\ ratings', '',regex=True))
#      51 df['availability'] = df['availability'].replace(r'\.', '',regex=True)
#      52
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
#     185                 values, set(), coerce_numeric=coerce_numeric
#     186             )
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,936" at position 2

# %%
new_df = df

# %%
pd.to_numeric(new_df['reviews'].replace(r'\ ratings', '',regex=True).replace(',',''),downcast ='signed')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,044"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17928\2251168689.py in <module>
# ----> 1 pd.to_numeric(new_df['reviews'].replace(r'\ ratings', '',regex=True).replace(',',''),downcast ='signed')
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
#     185                 values, set(), coerce_numeric=coerce_numeric
#     186             )
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1,044" at position 2

# %%
new_df
# Out:
#                                                 title  discounted_price  \
# 0   Fossil Women's Carmen Leather Shopper Tote Pur...            213.64
# 1    Fossil Women's Carmen Leather Tote Purse Handbag            224.00
# 2         Fossil Women's Rachel Satchel Purse Handbag             90.00
# 3   Fossil Women's Kinley Small Crossbody Purse Ha...             78.00
# 4   Fossil Women's Fiona Small Crossbody Purse Han...             90.47
# 5            Fossil Women's Rachel Tote Purse Handbag            169.99
# 6     Fossil Women's Jolie Leather Hobo Purse Handbag            146.86
# 7   Fossil Women's Fiona Large Crossbody Purse Han...            103.99
# 8   Fossil Women's Jacqueline Leather Satchel Purs...            127.67
# 9   Fossil Women's Ryder Leather Satchel Purse Han...            199.99
# 10  Fossil Women's Fiona Large Crossbody Purse Han...               NaN
# 11  Fossil Women's Harper Eco-Leather Large Flap C...            140.00
# 12  Fossil Women's Camilla Leather Convertible Bac...            149.99
# 13  Fossil Women's Jacqueline Leather Tote Purse H...            149.88
# 14        Fossil Women's Sydney Satchel Purse Handbag            110.35
# 15       Fossil Women's Maya Small Hobo Purse Handbag            187.82
# 16  Fossil Women's Brooke Leather Satchel Purse Ha...            152.11
# 17  Fossil Women's Sam Leather Shopper Tote Purse ...               NaN
# 14               NaN     NaN     4.4    354 ratings
# 15             -25.0  250.00     NaN    584 ratings
# 16               NaN     NaN     4.3    257 ratings
# 17               NaN     NaN     NaN     67 ratings
# 18             -26.0  180.00     4.6  1,063 ratings
# 19             -17.0  300.00     NaN      8 ratings
# 20             -20.0  330.00     NaN      5 ratings
# 21             -23.0  180.00     4.6  1,266 ratings
# 22               NaN     NaN     4.4    266 ratings
# 23             -40.0  230.00     4.4     86 ratings
# 24               NaN     NaN     4.5    215 ratings
# 25             -40.0  280.00     4.5     81 ratings
# 26             -45.0  180.00     4.5    315 ratings
# 27               NaN     NaN     NaN      2 ratings
# 28             -40.0  250.00     4.7      7 ratings
# 29               NaN     NaN     NaN      2 ratings
# 30             -30.0  200.00     NaN     50 ratings
# 31               NaN     NaN     4.7  2,240 ratings
# 32             -17.0  180.00     NaN      2 ratings
# 33             -10.0  118.80     NaN     62 ratings
# 34               NaN     NaN     4.5     11 ratings
# 35               NaN     NaN     4.3      5 ratings
# 36               NaN     NaN     4.4     17 ratings
# 37             -20.0  280.00     NaN
# 38               NaN     NaN     NaN      3 ratings
# 39               NaN     NaN     4.6    184 ratings
# 40             -30.0   90.00     4.7  2,271 ratings
# 41             -23.0  180.00     4.7     24 ratings
# 42               NaN     NaN     NaN       1 rating
# 43             -46.0  248.00     4.4     24 ratings
# 44             -55.0  150.00     NaN     33 ratings
# 45             -20.0  300.00     4.5     47 ratings
# 46             -13.0  200.00     4.7     12 ratings
# 47             -22.0  133.26     NaN      2 ratings
#
#                                availability
# 0                                 In Stock.
# 1                                 In Stock.
# 2                                 In Stock.
# 3                                 In Stock.
# 4                                 In Stock.
# 5                                 In Stock.
# 6                                 In Stock.
# 7                                 In Stock.
# 8                                 In Stock.
# 9                                 In Stock.
# 10                                In Stock.
# 11                                In Stock.
# 12                                In Stock.
# 13       Only 1 left in stock - order soon.
# 14
# 15                                In Stock.
# 16                                In Stock.
# 17                            Not Available
# 18                                In Stock.
# 19                                In Stock.
# 20                                In Stock.
# 21                                In Stock.
# 22                            Not Available
# 23                                In Stock.
# 24       Only 1 left in stock - order soon.
# 25                                In Stock.
# 26                                In Stock.
# 27                                In Stock.
# 28           Available to ship in 1-2 days.
# 29       Only 2 left in stock - order soon.
# 30                                In Stock.
# 31                                In Stock.
# 32                                In Stock.
# 33
# 34                                In Stock.
# 35       Only 2 left in stock - order soon.
# 36                                In Stock.
# 37                                In Stock.
# 38
# 39                                In Stock.
# 40                                In Stock.
# 41       Only 2 left in stock - order soon.
# 42
# 43                                In Stock.
# 44       Only 5 left in stock - order soon.
# 45                                In Stock.
# 46                                In Stock.
# 47  Only 2 left in stock (more on the way).
